# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Archivo csv.

# %%
# Lectura del archivo csv
root = "/content/drive/MyDrive/Universidad/4to Semestre/Periodo 3/Ethics/Phase3/conjunto_de_datos_imaief_entidad_mex2022_01.csv"
df_mex = pd.read_csv(root)

# %%
df_mex.shape # Dimensiones del dataframe
# Out:
# (20, 261)

# %%
df_mex.head(5) # Visualizar las primeras 5 filas del dataframe.
# Out:
#                                         Descriptores  2003|Enero  \
# 0  Índice de volumen físico base 2013=100|Activid...   80.253043
# 1  Índice de volumen físico base 2013=100|Activid...   50.481185
# 2  Índice de volumen físico base 2013=100|Activid...   52.333572
# 3  Índice de volumen físico base 2013=100|Activid...   55.397311
# 4  Índice de volumen físico base 2013=100|Activid...   88.571280
#
#    2003|Febrero  2003|Marzo  2003|Abril   2003|Mayo  2003|Junio  2003|Julio  \
# 0     81.340641   84.569443   86.202442   90.836791   92.157773   91.876012
# 1     53.455692   59.011888   64.544393   68.566207   67.903766   69.615847
# 2     48.802561   49.488793   48.413321   52.140219   55.738576   52.269155
# 3     61.286563   60.501481   62.664244   61.110179   67.214457   70.686213
# 4     88.808098   93.128418   94.760076  100.936642  100.996207  100.011689
#
#    2003|Agosto  2003|Septiembre  2003|Octubre  2003|Noviembre  2003|Diciembre  \
# ...

# %%
df_mex.tail(5) # Visualizar las últimas 5 filas del dataframe.
# Out:
#                                          Descriptores  2003|Enero  \
# 15        Variación acumulada|Actividades secundarias         NaN
# 16  Variación acumulada|Actividades secundarias|21...         NaN
# 17  Variación acumulada|Actividades secundarias|22...         NaN
# 18  Variación acumulada|Actividades secundarias|23...         NaN
# 19  Variación acumulada|Actividades secundarias|31...         NaN
#
#     2003|Febrero  2003|Marzo  2003|Abril  2003|Mayo  2003|Junio  2003|Julio  \
# 15           NaN         NaN         NaN        NaN         NaN         NaN
# 16           NaN         NaN         NaN        NaN         NaN         NaN
# 17           NaN         NaN         NaN        NaN         NaN         NaN
# 18           NaN         NaN         NaN        NaN         NaN         NaN
# 19           NaN         NaN         NaN        NaN         NaN         NaN
#
#     2003|Agosto  2003|Septiembre  2003|Octubre  2003|Noviembre  \
# ...

# %% [markdown]
# ## Datos nulos

# %%
pd.set_option('display.max_columns', None)
np.set_printoptions(threshold=np.inf)
pd.set_option('display.max_rows', None)

# %%
df_mex.isna().sum()
# Out:
# Descriptores           0
# 2003|Enero            15
# 2003|Febrero          15
# 2003|Marzo            15
# 2003|Abril            15
# 2003|Mayo             15
# 2003|Junio            15
# 2003|Julio            15
# 2003|Agosto           15
# 2003|Septiembre       15
# 2003|Octubre          15
# 2003|Noviembre        15
# 2003|Diciembre        15
# 2003|Anual            15
# 2004|Enero             0
# 2004|Febrero           0
# 2004|Marzo             0
# 2004|Abril             0
# 2004|Mayo              0
# 2004|Junio             0
# 2004|Julio             0
# 2004|Agosto            0
# 2004|Septiembre        0
# 2004|Octubre           0
# 2004|Noviembre         0
# 2004|Diciembre         0
# 2004|Anual             0
# 2005|Enero             0
# 2005|Febrero           0
# 2005|Marzo             0
# 2005|Abril             0
# 2005|Mayo              0
# 2005|Junio             0
# 2005|Julio             0
# 2005|Agosto            0
# 2005|Septiembre        0
# 2005|Octubre           0
# ...

# %%
# Fechas que tienen datos nulos.
df_na = df_mex.isna().sum()
df_na[df_na != 0]
# Out:
# 2003|Enero         15
# 2003|Febrero       15
# 2003|Marzo         15
# 2003|Abril         15
# 2003|Mayo          15
# 2003|Junio         15
# 2003|Julio         15
# 2003|Agosto        15
# 2003|Septiembre    15
# 2003|Octubre       15
# 2003|Noviembre     15
# 2003|Diciembre     15
# 2003|Anual         15
# 2022|Febrero       20
# 2022|Marzo         20
# 2022|Abril         20
# 2022|Mayo          20
# 2022|Junio         20
# 2022|Julio         20
# 2022|Agosto        20
# 2022|Septiembre    20
# 2022|Octubre       20
# 2022|Noviembre     20
# 2022|Diciembre     20
# 2022|Anual         20
# dtype: int64

# %%
# Porcentaje de datos nulos respecto al total.
df_mex.isna().sum()/df_mex.shape[0]*100
# Out:
# Descriptores            0.0
# 2003|Enero             75.0
# 2003|Febrero           75.0
# 2003|Marzo             75.0
# 2003|Abril             75.0
# 2003|Mayo              75.0
# 2003|Junio             75.0
# 2003|Julio             75.0
# 2003|Agosto            75.0
# 2003|Septiembre        75.0
# 2003|Octubre           75.0
# 2003|Noviembre         75.0
# 2003|Diciembre         75.0
# 2003|Anual             75.0
# 2004|Enero              0.0
# 2004|Febrero            0.0
# 2004|Marzo              0.0
# 2004|Abril              0.0
# 2004|Mayo               0.0
# 2004|Junio              0.0
# 2004|Julio              0.0
# 2004|Agosto             0.0
# 2004|Septiembre         0.0
# 2004|Octubre            0.0
# 2004|Noviembre          0.0
# 2004|Diciembre          0.0
# 2004|Anual              0.0
# 2005|Enero              0.0
# 2005|Febrero            0.0
# 2005|Marzo              0.0
# 2005|Abril              0.0
# 2005|Mayo               0.0
# 2005|Junio              0.0
# ...

# %%
# Variables que tienen TODOS sus datos nulos (100% de NA)
df_na2 = df_mex.isna().sum()/df_mex.shape[0]*100 
df_na2 = df_na2[df_na2 == 100]
df_na2
# Out:
# 2022|Febrero       100.0
# 2022|Marzo         100.0
# 2022|Abril         100.0
# 2022|Mayo          100.0
# 2022|Junio         100.0
# 2022|Julio         100.0
# 2022|Agosto        100.0
# 2022|Septiembre    100.0
# 2022|Octubre       100.0
# 2022|Noviembre     100.0
# 2022|Diciembre     100.0
# 2022|Anual         100.0
# dtype: float64

# %%
# Variables que más del 70% de sus datos nulos. Excluyendo las variables cuyos datos son nulos en su totalidad.
df_na3 = df_mex.isna().sum()/df_mex.shape[0]*100 
df_na3 = df_na3[(df_na3 >= 70) & (df_na3 < 100)]
df_na3
# Out:
# 2003|Enero         75.0
# 2003|Febrero       75.0
# 2003|Marzo         75.0
# 2003|Abril         75.0
# 2003|Mayo          75.0
# 2003|Junio         75.0
# 2003|Julio         75.0
# 2003|Agosto        75.0
# 2003|Septiembre    75.0
# 2003|Octubre       75.0
# 2003|Noviembre     75.0
# 2003|Diciembre     75.0
# 2003|Anual         75.0
# dtype: float64

# %% [markdown]
# ## Eliminando datos nulos

# %% [markdown]
# ### Variables con datos nulos en su totalidad

# %%
# Dado que la totalidad de sus datos son nulos, se considero pertinente eliminar dichas variables del conjunto de datos.
NA = df_na2.index.values
NA
# Out:
# array(['2022|Febrero', '2022|Marzo', '2022|Abril', '2022|Mayo',
#        '2022|Junio', '2022|Julio', '2022|Agosto', '2022|Septiembre',
#        '2022|Octubre', '2022|Noviembre', '2022|Diciembre', '2022|Anual'],
#       dtype=object)

# %%
len(list(NA)) # Cantidad de variables con datos nulos
# Out:
# 12

# %%
df_mex2 = df_mex.drop(NA, axis=1)

# %%
df_mex2.shape # Dimensiones del dataframe
# Out:
# (20, 249)

# %%
abs(df_mex2.shape[1] - df_mex.shape[1])
# Out:
# 12

# %% [markdown]
# La diferencia de las dimensiones de las columnas entre df_mex2 (249)  y df_mex (261) corresponde a la cantidad de variables con datos nulos (12)

# %% [markdown]
# ### Variables con datos nulos mayores o iguales al 70% e inferiores al 100%

# %%
NA_2 = df_na3.index.values
NA_2
# Out:
# array(['2003|Enero', '2003|Febrero', '2003|Marzo', '2003|Abril',
#        '2003|Mayo', '2003|Junio', '2003|Julio', '2003|Agosto',
#        '2003|Septiembre', '2003|Octubre', '2003|Noviembre',
#        '2003|Diciembre', '2003|Anual'], dtype=object)

# %%
len(list(NA_2)) # Cantidad de variables con datos nulos
# Out:
# 13

# %%
df_mex3 = df_mex2.drop(NA_2, axis=1)

# %%
df_mex3.shape # Dimensiones del dataframe
# Out:
# (20, 236)

# %%
abs(df_mex3.shape[1] - df_mex2.shape[1])
# Out:
# 13

# %% [markdown]
# La diferencia de las dimensiones de las columnas entre df_mex2 (249)  y df_mex3 (236) corresponde a la cantidad de variables con datos nulos (13)

# %% [markdown]
# ## Separación por descriptores

# %%
lst_descriptores = df_mex3["Descriptores"]
lst_descriptores
# Out:
# 0     Índice de volumen físico base 2013=100|Activid...
# 1     Índice de volumen físico base 2013=100|Activid...
# 2     Índice de volumen físico base 2013=100|Activid...
# 3     Índice de volumen físico base 2013=100|Activid...
# 4     Índice de volumen físico base 2013=100|Activid...
# 5     Variación porcentual anual|Actividades secunda...
# 6     Variación porcentual anual|Actividades secunda...
# 7     Variación porcentual anual|Actividades secunda...
# 8     Variación porcentual anual|Actividades secunda...
# 9     Variación porcentual anual|Actividades secunda...
# 10    Contribución a la variación de las actividades...
# 11    Contribución a la variación de las actividades...
# 12    Contribución a la variación de las actividades...
# 13    Contribución a la variación de las actividades...
# 14    Contribución a la variación de las actividades...
# 15          Variación acumulada|Actividades secundarias
# 16    Variación acumulada|Actividades secundarias|21...
# ...

# %%
# Desplegar la lista por sus nombres completos
index = 0
for i in lst_descriptores:
  print("["+ str(index) + "]",i)
  index += 1
# Out:
# [0] Índice de volumen físico base 2013=100|Actividades secundarias
# [1] Índice de volumen físico base 2013=100|Actividades secundarias|21---Minería
# [2] Índice de volumen físico base 2013=100|Actividades secundarias|22---Generación, transmisión y distribución de energía eléctrica, suministro de agua y de gas por ductos al consumidor final
# [3] Índice de volumen físico base 2013=100|Actividades secundarias|23---Construcción
# [4] Índice de volumen físico base 2013=100|Actividades secundarias|31-33---Industrias manufactureras
# [5] Variación porcentual anual|Actividades secundarias
# [6] Variación porcentual anual|Actividades secundarias|21---Minería
# [7] Variación porcentual anual|Actividades secundarias|22---Generación, transmisión y distribución de energía eléctrica, suministro de agua y de gas por ductos al consumidor final
# [8] Variación porcentual anual|Actividades secundarias|23---Construcción
# ...

# %%
index = 0
volFisicoBase = "Índice de volumen físico base 2013=100"
arr_VFB = [] # Arreglo de volumen físico base

varPorcAnual = "Variación porcentual anual"
arr_VPA = []

varActSecund = "Contribución a la variación de las actividades secundarias"
arr_VAS = []

varAcum = "Variación acumulada"
arr_VA = []

for i in lst_descriptores:
  if volFisicoBase in i:
    arr_VFB.append(index)
  elif varPorcAnual in i:
    arr_VPA.append(index)
  elif varActSecund in i:
    arr_VAS.append(index)
  elif varAcum in i:
    arr_VA.append(index)
  index += 1

# %% [markdown]
# ## Cambiando el nombre de las filas

# %%
lst_descriptores = list(df_mex3["Descriptores"])

# %%
df_mex4 = df_mex3.set_axis(lst_descriptores)
df_mex4
# Out:
#                                                                                          Descriptores  \
# Índice de volumen físico base 2013=100|Activida...  Índice de volumen físico base 2013=100|Activid...
# Índice de volumen físico base 2013=100|Activida...  Índice de volumen físico base 2013=100|Activid...
# Índice de volumen físico base 2013=100|Activida...  Índice de volumen físico base 2013=100|Activid...
# Índice de volumen físico base 2013=100|Activida...  Índice de volumen físico base 2013=100|Activid...
# Índice de volumen físico base 2013=100|Activida...  Índice de volumen físico base 2013=100|Activid...
# Variación porcentual anual|Actividades secundarias  Variación porcentual anual|Actividades secunda...
# Variación porcentual anual|Actividades secundar...  Variación porcentual anual|Actividades secunda...
# Variación porcentual anual|Actividades secundar...  Variación porcentual anual|Actividades secunda...
# ...

# %%
df_mex4.drop("Descriptores",axis=1,inplace=True) # Eliminando columna de Descriptores

# %%
df_mex4.head(5)
# Out:
#                                                     2004|Enero  2004|Febrero  \
# Índice de volumen físico base 2013=100|Activida...   84.330474     86.587453
# Índice de volumen físico base 2013=100|Activida...   61.687981     66.392966
# Índice de volumen físico base 2013=100|Activida...   59.058134     56.943105
# Índice de volumen físico base 2013=100|Activida...   69.490142     74.289658
# Índice de volumen físico base 2013=100|Activida...   89.971708     91.888161
#
#                                                     2004|Marzo  2004|Abril  \
# Índice de volumen físico base 2013=100|Activida...   92.602809   87.112190
# Índice de volumen físico base 2013=100|Activida...   69.722894   64.417115
# Índice de volumen físico base 2013=100|Activida...   59.915421   55.784922
# Índice de volumen físico base 2013=100|Activida...   75.041443   71.114732
# Índice de volumen físico base 2013=100|Activida...   99.407642   93.448462
#
# ...

# %% [markdown]
# ### Índice de volumen físico base 2013=100

# %%
print(arr_VFB) # Filas del df correspondientes a volumen físico base.
# Out:
# [0, 1, 2, 3, 4]

# %%
df_arr_VFB = df_mex4.iloc[arr_VFB]
df_arr_VFB
# Out:
#                                                     2004|Enero  2004|Febrero  \
# Índice de volumen físico base 2013=100|Activida...   84.330474     86.587453
# Índice de volumen físico base 2013=100|Activida...   61.687981     66.392966
# Índice de volumen físico base 2013=100|Activida...   59.058134     56.943105
# Índice de volumen físico base 2013=100|Activida...   69.490142     74.289658
# Índice de volumen físico base 2013=100|Activida...   89.971708     91.888161
#
#                                                     2004|Marzo  2004|Abril  \
# Índice de volumen físico base 2013=100|Activida...   92.602809   87.112190
# Índice de volumen físico base 2013=100|Activida...   69.722894   64.417115
# Índice de volumen físico base 2013=100|Activida...   59.915421   55.784922
# Índice de volumen físico base 2013=100|Activida...   75.041443   71.114732
# Índice de volumen físico base 2013=100|Activida...   99.407642   93.448462
#
# ...

# %%
lst_colNames = df_mex4.columns.values
lst_colNames
# Out:
# array(['2004|Enero', '2004|Febrero', '2004|Marzo', '2004|Abril',
#        '2004|Mayo', '2004|Junio', '2004|Julio', '2004|Agosto',
#        '2004|Septiembre', '2004|Octubre', '2004|Noviembre',
#        '2004|Diciembre', '2004|Anual', '2005|Enero', '2005|Febrero',
#        '2005|Marzo', '2005|Abril', '2005|Mayo', '2005|Junio',
#        '2005|Julio', '2005|Agosto', '2005|Septiembre', '2005|Octubre',
#        '2005|Noviembre', '2005|Diciembre', '2005|Anual', '2006|Enero',
#        '2006|Febrero', '2006|Marzo', '2006|Abril', '2006|Mayo',
#        '2006|Junio', '2006|Julio', '2006|Agosto', '2006|Septiembre',
#        '2006|Octubre', '2006|Noviembre', '2006|Diciembre', '2006|Anual',
#        '2007|Enero', '2007|Febrero', '2007|Marzo', '2007|Abril',
#        '2007|Mayo', '2007|Junio', '2007|Julio', '2007|Agosto',
#        '2007|Septiembre', '2007|Octubre', '2007|Noviembre',
#        '2007|Diciembre', '2007|Anual', '2008|Enero', '2008|Febrero',
# ...

# %%
lst_colNames[1] # Primera fecha del conjunto de datos.
# Out:
# '2004|Febrero'

# %%
lst_colNames[-1] # Última fecha del conjunto de datos-
# Out:
# '2022|Enero<P>'

# %%
lst_VFB_2004 = []
lst_VFB_2005 = []
lst_VFB_2006 = []
lst_VFB_2007 = []
lst_VFB_2008 = []
lst_VFB_2009 = []
lst_VFB_2010 = []
lst_VFB_2011 = []
lst_VFB_2012 = []
lst_VFB_2013 = []
lst_VFB_2014 = []
lst_VFB_2015 = []
lst_VFB_2016 = []
lst_VFB_2017 = []
lst_VFB_2018 = []
lst_VFB_2019 = []
lst_VFB_2020 = []
lst_VFB_2021 = []
lst_VFB_2022 = []

for i in lst_colNames:
  if "2004" in i:
    lst_VFB_2004.append(i)
  if "2005" in i:
    lst_VFB_2005.append(i)
  if "2006" in i:
    lst_VFB_2006.append(i)
  if "2007" in i:
    lst_VFB_2007.append(i)
  if "2008" in i:
    lst_VFB_2008.append(i)
  if "2009" in i:
    lst_VFB_2009.append(i)
  if "2010" in i:
    lst_VFB_2010.append(i)
  if "2011" in i:
    lst_VFB_2011.append(i)
  if "2012" in i:
    lst_VFB_2012.append(i)
  if "2013" in i:
    lst_VFB_2013.append(i)
  if "2014" in i:
    lst_VFB_2014.append(i)
  if "2015" in i:
    lst_VFB_2015.append(i)
  if "2016" in i:
    lst_VFB_2016.append(i)
  if "2017" in i:
    lst_VFB_2017.append(i)
  if "2018" in i:
    lst_VFB_2018.append(i)
  if "2019" in i:
    lst_VFB_2019.append(i)
  if "2020" in i:
    lst_VFB_2020.append(i)
  if "2021" in i:
    lst_VFB_2021.append(i)
  if "2022" in i:
    lst_VFB_2022.append(i)

# %%
df_VFB_2004 = df_arr_VFB.loc[:,lst_VFB_2004]
df_VFB_2005 = df_arr_VFB.loc[:,lst_VFB_2005]
df_VFB_2006 = df_arr_VFB.loc[:,lst_VFB_2006]
df_VFB_2007 = df_arr_VFB.loc[:,lst_VFB_2007]
df_VFB_2008 = df_arr_VFB.loc[:,lst_VFB_2008]
df_VFB_2009 = df_arr_VFB.loc[:,lst_VFB_2009]

df_VFB_2010 = df_arr_VFB.loc[:,lst_VFB_2010]
df_VFB_2011 = df_arr_VFB.loc[:,lst_VFB_2011]
df_VFB_2012 = df_arr_VFB.loc[:,lst_VFB_2012]
df_VFB_2013 = df_arr_VFB.loc[:,lst_VFB_2013]
df_VFB_2014 = df_arr_VFB.loc[:,lst_VFB_2014]
df_VFB_2015 = df_arr_VFB.loc[:,lst_VFB_2015]
df_VFB_2016 = df_arr_VFB.loc[:,lst_VFB_2016]
df_VFB_2017 = df_arr_VFB.loc[:,lst_VFB_2017]
df_VFB_2018 = df_arr_VFB.loc[:,lst_VFB_2018]
df_VFB_2019 = df_arr_VFB.loc[:,lst_VFB_2019]

df_VFB_2020 = df_arr_VFB.loc[:,lst_VFB_2020]
df_VFB_2021 = df_arr_VFB.loc[:,lst_VFB_2021]
df_VFB_2022 = df_arr_VFB.loc[:,lst_VFB_2022]

# %% [markdown]
# #### Manipulación de los dataFrame

# %%
months = ["January","February","March","April","May","June","July",
        "August","September","October","November","December"]

# %% [markdown]
# ###### 2004

# %%
df_VFB_2004_2 = df_VFB_2004.iloc[:, 0:-1]
df_VFB_2004_2
# Out:
#                                                     2004|Enero  2004|Febrero  \
# Índice de volumen físico base 2013=100|Activida...   84.330474     86.587453
# Índice de volumen físico base 2013=100|Activida...   61.687981     66.392966
# Índice de volumen físico base 2013=100|Activida...   59.058134     56.943105
# Índice de volumen físico base 2013=100|Activida...   69.490142     74.289658
# Índice de volumen físico base 2013=100|Activida...   89.971708     91.888161
#
#                                                     2004|Marzo  2004|Abril  \
# Índice de volumen físico base 2013=100|Activida...   92.602809   87.112190
# Índice de volumen físico base 2013=100|Activida...   69.722894   64.417115
# Índice de volumen físico base 2013=100|Activida...   59.915421   55.784922
# Índice de volumen físico base 2013=100|Activida...   75.041443   71.114732
# Índice de volumen físico base 2013=100|Activida...   99.407642   93.448462
#
# ...

# %%
df_VFB_2004_2.columns = months
df_VFB_2004_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                       January   February  \
# Índice de volumen físico base 2013=100|Activida...  84.330474  86.587453
# Índice de volumen físico base 2013=100|Activida...  61.687981  66.392966
# Índice de volumen físico base 2013=100|Activida...  59.058134  56.943105
# Índice de volumen físico base 2013=100|Activida...  69.490142  74.289658
# Índice de volumen físico base 2013=100|Activida...  89.971708  91.888161
#
#                                                         March      April  \
# Índice de volumen físico base 2013=100|Activida...  92.602809  87.112190
# Índice de volumen físico base 2013=100|Activida...  69.722894  64.417115
# Índice de volumen físico base 2013=100|Activida...  59.915421  55.784922
# Índice de volumen físico base 2013=100|Activida...  75.041443  71.114732
# Índice de volumen físico base 2013=100|Activida...  99.407642  93.448462
#
#                                                           May       June  \
# ...

# %% [markdown]
# ###### 2005

# %%
df_VFB_2005_2 = df_VFB_2005.iloc[:, 0:-1]
df_VFB_2005_2.columns = months
df_VFB_2005_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                       January   February  \
# Índice de volumen físico base 2013=100|Activida...  85.889674  86.570714
# Índice de volumen físico base 2013=100|Activida...  76.121418  74.181288
# Índice de volumen físico base 2013=100|Activida...  67.271811  62.128480
# Índice de volumen físico base 2013=100|Activida...  74.499026  74.374952
# Índice de volumen físico base 2013=100|Activida...  90.042278  91.360410
#
#                                                         March      April  \
# Índice de volumen físico base 2013=100|Activida...  86.654623  89.630573
# Índice de volumen físico base 2013=100|Activida...  69.900167  69.524650
# Índice de volumen físico base 2013=100|Activida...  63.570922  52.188551
# Índice de volumen físico base 2013=100|Activida...  74.051548  75.148357
# Índice de volumen físico base 2013=100|Activida...  91.517635  95.988684
#
#                                                           May       June  \
# ...

# %% [markdown]
# ###### 2006

# %%
df_VFB_2006_2 = df_VFB_2006.iloc[:, 0:-1]
df_VFB_2006_2.columns = months
df_VFB_2006_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                       January   February  \
# Índice de volumen físico base 2013=100|Activida...  86.795646  86.888930
# Índice de volumen físico base 2013=100|Activida...  70.119221  64.928142
# Índice de volumen físico base 2013=100|Activida...  58.543466  61.081608
# Índice de volumen físico base 2013=100|Activida...  76.091485  84.197095
# Índice de volumen físico base 2013=100|Activida...  91.564522  89.671527
#
#                                                         March      April  \
# Índice de volumen físico base 2013=100|Activida...  94.641830  88.056529
# Índice de volumen físico base 2013=100|Activida...  74.035396  71.823573
# Índice de volumen físico base 2013=100|Activida...  63.451480  65.626012
# Índice de volumen físico base 2013=100|Activida...  96.024254  85.582532
# Índice de volumen físico base 2013=100|Activida...  96.807944  90.460705
#
#                                                            May        June  \
# ...

# %% [markdown]
# ###### 2007

# %%
df_VFB_2007_2 = df_VFB_2007.iloc[:, 0:-1]
df_VFB_2007_2.columns = months
df_VFB_2007_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                       January   February  \
# Índice de volumen físico base 2013=100|Activida...  88.175611  85.551580
# Índice de volumen físico base 2013=100|Activida...  70.644334  66.700573
# Índice de volumen físico base 2013=100|Activida...  78.534663  76.863716
# Índice de volumen físico base 2013=100|Activida...  72.453591  80.561210
# Índice de volumen físico base 2013=100|Activida...  92.860609  87.643712
#
#                                                         March      April  \
# Índice de volumen físico base 2013=100|Activida...  95.791303  88.567246
# Índice de volumen físico base 2013=100|Activida...  78.124650  71.008063
# Índice de volumen físico base 2013=100|Activida...  78.358812  71.374028
# Índice de volumen físico base 2013=100|Activida...  91.143088  88.376071
# Índice de volumen físico base 2013=100|Activida...  98.388752  90.088060
#
#                                                           May        June  \
# ...

# %% [markdown]
# ###### 2008

# %%
df_VFB_2008_2 = df_VFB_2008.iloc[:, 0:-1]
df_VFB_2008_2.columns = months
df_VFB_2008_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                       January   February  \
# Índice de volumen físico base 2013=100|Activida...  88.616238  89.815882
# Índice de volumen físico base 2013=100|Activida...  72.717697  70.137427
# Índice de volumen físico base 2013=100|Activida...  83.798131  84.168728
# Índice de volumen físico base 2013=100|Activida...  90.577884  83.499622
# Índice de volumen físico base 2013=100|Activida...  88.741733  92.025618
#
#                                                         March       April  \
# Índice de volumen físico base 2013=100|Activida...  88.563899   96.855969
# Índice de volumen físico base 2013=100|Activida...  71.321001   74.996885
# Índice de volumen físico base 2013=100|Activida...  80.529297   74.102655
# Índice de volumen físico base 2013=100|Activida...  84.304505   91.384435
# Índice de volumen físico base 2013=100|Activida...  90.411160  100.085403
#
#                                                           May       June  \
# ...

# %% [markdown]
# ###### 2009

# %%
df_VFB_2009_2 = df_VFB_2009.iloc[:, 0:-1]
df_VFB_2009_2.columns = months
df_VFB_2009_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                       January   February  \
# Índice de volumen físico base 2013=100|Activida...  81.928780  77.525448
# Índice de volumen físico base 2013=100|Activida...  74.724060  66.187057
# Índice de volumen físico base 2013=100|Activida...  89.770402  90.150033
# Índice de volumen físico base 2013=100|Activida...  80.216964  65.244095
# Índice de volumen físico base 2013=100|Activida...  81.908761  79.750798
#
#                                                         March      April  \
# Índice de volumen físico base 2013=100|Activida...  84.802630  83.597481
# Índice de volumen físico base 2013=100|Activida...  76.772607  82.693700
# Índice de volumen físico base 2013=100|Activida...  98.972298  96.373515
# Índice de volumen físico base 2013=100|Activida...  77.454551  89.043578
# Índice de volumen físico base 2013=100|Activida...  85.695959  81.433945
#
#                                                           May       June  \
# ...

# %% [markdown]
# ###### 2010

# %%
df_VFB_2010_2 = df_VFB_2010.iloc[:, 0:-1]
df_VFB_2010_2.columns = months
df_VFB_2010_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...   90.445081   84.166070
# Índice de volumen físico base 2013=100|Activida...   83.737474   74.162127
# Índice de volumen físico base 2013=100|Activida...   96.210262  100.374278
# Índice de volumen físico base 2013=100|Activida...  119.263328   84.714348
# Índice de volumen físico base 2013=100|Activida...   83.311505   83.075179
#
#                                                          March       April  \
# Índice de volumen físico base 2013=100|Activida...   96.499915   93.866280
# Índice de volumen físico base 2013=100|Activida...   85.788095   87.998701
# Índice de volumen físico base 2013=100|Activida...   99.833449   89.414845
# Índice de volumen físico base 2013=100|Activida...  107.290421  124.405052
# Índice de volumen físico base 2013=100|Activida...   93.880316   87.018270
#
# ...

# %% [markdown]
# ###### 2011

# %%
df_VFB_2011_2 = df_VFB_2011.iloc[:, 0:-1]
df_VFB_2011_2.columns = months
df_VFB_2011_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...   90.552322   90.180746
# Índice de volumen físico base 2013=100|Activida...   78.263290   79.160621
# Índice de volumen físico base 2013=100|Activida...  112.567105  115.335477
# Índice de volumen físico base 2013=100|Activida...   93.435942   88.523150
# Índice de volumen físico base 2013=100|Activida...   88.541695   89.010367
#
#                                                          March       April  \
# Índice de volumen físico base 2013=100|Activida...   97.059298   93.044393
# Índice de volumen físico base 2013=100|Activida...   82.353781   82.536622
# Índice de volumen físico base 2013=100|Activida...  112.790038  104.534831
# Índice de volumen físico base 2013=100|Activida...   79.565052   93.393705
# Índice de volumen físico base 2013=100|Activida...  100.361824   92.335710
#
# ...

# %% [markdown]
# ###### 2012

# %%
df_VFB_2012_2 = df_VFB_2012.iloc[:, 0:-1]
df_VFB_2012_2.columns = months
df_VFB_2012_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                       January   February  \
# Índice de volumen físico base 2013=100|Activida...  94.813323  94.775744
# Índice de volumen físico base 2013=100|Activida...  88.604886  87.825100
# Índice de volumen físico base 2013=100|Activida...  89.326918  93.278400
# Índice de volumen físico base 2013=100|Activida...  86.645295  91.110471
# Índice de volumen físico base 2013=100|Activida...  97.233431  95.862373
#
#                                                          March      April  \
# Índice de volumen físico base 2013=100|Activida...   99.095622  92.833209
# Índice de volumen físico base 2013=100|Activida...   84.405664  88.838673
# Índice de volumen físico base 2013=100|Activida...   87.499264  83.848747
# Índice de volumen físico base 2013=100|Activida...   83.255858  89.308531
# Índice de volumen físico base 2013=100|Activida...  103.898006  94.357207
#
#                                                            May        June  \
# ...

# %% [markdown]
# ###### 2013

# %%
df_VFB_2013_2 = df_VFB_2013.iloc[:, 0:-1]
df_VFB_2013_2.columns = months
df_VFB_2013_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...   99.620169   97.579737
# Índice de volumen físico base 2013=100|Activida...   99.660588   89.737308
# Índice de volumen físico base 2013=100|Activida...  103.466849  100.768510
# Índice de volumen físico base 2013=100|Activida...   96.742969  105.481016
# Índice de volumen físico base 2013=100|Activida...  100.036241   95.609731
#
#                                                         March       April  \
# Índice de volumen físico base 2013=100|Activida...  94.071467  100.639075
# Índice de volumen físico base 2013=100|Activida...  95.990850  100.865878
# Índice de volumen físico base 2013=100|Activida...  97.571980   99.221017
# Índice de volumen físico base 2013=100|Activida...  87.837187   94.035697
# Índice de volumen físico base 2013=100|Activida...  95.278218  102.301598
#
# ...

# %% [markdown]
# ###### 2014

# %%
df_VFB_2014_2 = df_VFB_2014.iloc[:, 0:-1]
df_VFB_2014_2.columns = months
df_VFB_2014_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...   94.734400   93.332718
# Índice de volumen físico base 2013=100|Activida...   99.704180   88.255494
# Índice de volumen físico base 2013=100|Activida...  101.870447   97.227915
# Índice de volumen físico base 2013=100|Activida...   88.101038  102.503996
# Índice de volumen físico base 2013=100|Activida...   95.734666   90.967425
#
#                                                          March       April  \
# Índice de volumen físico base 2013=100|Activida...   97.603371   97.597043
# Índice de volumen físico base 2013=100|Activida...   98.625766   96.288573
# Índice de volumen físico base 2013=100|Activida...  104.614230  106.859026
# Índice de volumen físico base 2013=100|Activida...   89.577226   99.593076
# Índice de volumen físico base 2013=100|Activida...   99.006966   96.502698
#
# ...

# %% [markdown]
# ###### 2015

# %%
df_VFB_2015_2 = df_VFB_2015.iloc[:, 0:-1]
df_VFB_2015_2.columns = months
df_VFB_2015_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...   96.179168   93.839680
# Índice de volumen físico base 2013=100|Activida...   91.300606   88.097126
# Índice de volumen físico base 2013=100|Activida...  118.676542  111.803283
# Índice de volumen físico base 2013=100|Activida...   94.218248   92.221818
# Índice de volumen físico base 2013=100|Activida...   95.165405   93.072511
#
#                                                          March      April  \
# Índice de volumen físico base 2013=100|Activida...   96.794384  97.031225
# Índice de volumen físico base 2013=100|Activida...   96.080412  97.632336
# Índice de volumen físico base 2013=100|Activida...  109.658546  97.071828
# Índice de volumen físico base 2013=100|Activida...   86.888304  98.233900
# Índice de volumen físico base 2013=100|Activida...   98.267032  96.733101
#
# ...

# %% [markdown]
# ###### 2016

# %%
df_VFB_2016_2 = df_VFB_2016.iloc[:, 0:-1]
df_VFB_2016_2.columns = months
df_VFB_2016_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...   96.384559   95.069415
# Índice de volumen físico base 2013=100|Activida...   95.529828   94.804252
# Índice de volumen físico base 2013=100|Activida...  119.753954  114.338522
# Índice de volumen físico base 2013=100|Activida...   99.259771  107.545028
# Índice de volumen físico base 2013=100|Activida...   94.096874   90.776602
#
#                                                          March       April  \
# Índice de volumen físico base 2013=100|Activida...   93.538695   97.827583
# Índice de volumen físico base 2013=100|Activida...   99.535851  107.252026
# Índice de volumen físico base 2013=100|Activida...  110.663375   94.258310
# Índice de volumen físico base 2013=100|Activida...  101.701024  120.713390
# Índice de volumen físico base 2013=100|Activida...   90.317173   92.487947
#
# ...

# %% [markdown]
# ###### 2017

# %%
df_VFB_2017_2 = df_VFB_2017.iloc[:, 0:-1]
df_VFB_2017_2.columns = months
df_VFB_2017_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...   99.548226   96.386560
# Índice de volumen físico base 2013=100|Activida...   90.330674   83.520040
# Índice de volumen físico base 2013=100|Activida...  103.465104  107.430026
# Índice de volumen físico base 2013=100|Activida...  105.316667  102.487273
# Índice de volumen físico base 2013=100|Activida...   98.056501   94.381381
#
#                                                          March      April  \
# Índice de volumen físico base 2013=100|Activida...  103.764664  93.370117
# Índice de volumen físico base 2013=100|Activida...   96.435724  90.750591
# Índice de volumen físico base 2013=100|Activida...  102.521060  94.141712
# Índice de volumen físico base 2013=100|Activida...  111.110538  94.862862
# Índice de volumen físico base 2013=100|Activida...  102.225255  93.004650
#
# ...

# %% [markdown]
# ###### 2018

# %%
df_VFB_2018_2 = df_VFB_2018.iloc[:, 0:-1]
df_VFB_2018_2.columns = months
df_VFB_2018_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...  110.332642  107.097789
# Índice de volumen físico base 2013=100|Activida...   99.016023   97.733796
# Índice de volumen físico base 2013=100|Activida...  120.940883  121.507923
# Índice de volumen físico base 2013=100|Activida...  141.573062  150.416447
# Índice de volumen físico base 2013=100|Activida...  102.363100   95.965288
#
#                                                          March       April  \
# Índice de volumen físico base 2013=100|Activida...  107.209135  109.265185
# Índice de volumen físico base 2013=100|Activida...  101.805283   98.100141
# Índice de volumen físico base 2013=100|Activida...  110.186102  110.802217
# Índice de volumen físico base 2013=100|Activida...  138.830180  139.192962
# Índice de volumen físico base 2013=100|Activida...   99.582058  102.233242
#
# ...

# %% [markdown]
# ###### 2019

# %%
df_VFB_2019_2 = df_VFB_2019.iloc[:, 0:-1]
df_VFB_2019_2.columns = months
df_VFB_2019_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...  105.497617  100.419411
# Índice de volumen físico base 2013=100|Activida...   89.554046   87.676546
# Índice de volumen físico base 2013=100|Activida...   99.467669  103.556852
# Índice de volumen físico base 2013=100|Activida...  116.816168  123.502715
# Índice de volumen físico base 2013=100|Activida...  103.485997   94.927380
#
#                                                          March       April  \
# Índice de volumen físico base 2013=100|Activida...  103.112695   98.339472
# Índice de volumen físico base 2013=100|Activida...   96.423243   91.624133
# Índice de volumen físico base 2013=100|Activida...   98.071812  103.425255
# Índice de volumen físico base 2013=100|Activida...  112.183273  111.940120
# Índice de volumen físico base 2013=100|Activida...  101.416437   94.866491
#
# ...

# %% [markdown]
# ###### 2020

# %%
df_VFB_2020_2 = df_VFB_2020.iloc[:, 0:-1]
df_VFB_2020_2.columns = months
df_VFB_2020_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...  100.962139   99.643316
# Índice de volumen físico base 2013=100|Activida...   99.953746   96.847119
# Índice de volumen físico base 2013=100|Activida...  109.695633  114.665654
# Índice de volumen físico base 2013=100|Activida...  118.634755  123.572532
# Índice de volumen físico base 2013=100|Activida...   96.177148   92.966028
#
#                                                          March       April  \
# Índice de volumen físico base 2013=100|Activida...   99.093983   73.339774
# Índice de volumen físico base 2013=100|Activida...   99.070792   92.851978
# Índice de volumen físico base 2013=100|Activida...  108.483151  109.081308
# Índice de volumen físico base 2013=100|Activida...  118.362584   90.058953
# Índice de volumen físico base 2013=100|Activida...   93.868649   66.577907
#
# ...

# %% [markdown]
# ###### 2021

# %%
df_VFB_2021_2 = df_VFB_2021.iloc[:, 0:-1]
df_VFB_2021_2.columns = months
df_VFB_2021_2.head(5) # Cambiar el nombre a los meses.
# Out:
#                                                        January    February  \
# Índice de volumen físico base 2013=100|Activida...   95.564927   93.493756
# Índice de volumen físico base 2013=100|Activida...  108.614117  105.472775
# Índice de volumen físico base 2013=100|Activida...  131.412813  121.294813
# Índice de volumen físico base 2013=100|Activida...  107.733057  115.078244
# Índice de volumen físico base 2013=100|Activida...   89.981029   86.248695
#
#                                                          March       April  \
# Índice de volumen físico base 2013=100|Activida...   99.179348   95.795175
# Índice de volumen físico base 2013=100|Activida...  112.696085  105.135342
# Índice de volumen físico base 2013=100|Activida...  104.703080  114.375381
# Índice de volumen físico base 2013=100|Activida...  118.002932  110.299324
# Índice de volumen físico base 2013=100|Activida...   94.108118   90.912815
#
# ...

# %% [markdown]
# #### Gráficos

# %% [markdown]
# ##### Índice de volumen físico base 2013=100|Actividades secundarias

# %%
Y_VFB_2004_2 = df_VFB_2004_2.iloc[0]
Y_VFB_2005_2 = df_VFB_2005_2.iloc[0]
Y_VFB_2006_2 = df_VFB_2006_2.iloc[0]
Y_VFB_2007_2 = df_VFB_2007_2.iloc[0]
Y_VFB_2008_2 = df_VFB_2008_2.iloc[0]
Y_VFB_2009_2 = df_VFB_2009_2.iloc[0]

Y_VFB_2010_2 = df_VFB_2010_2.iloc[0]
Y_VFB_2011_2 = df_VFB_2011_2.iloc[0]
Y_VFB_2012_2 = df_VFB_2012_2.iloc[0]
Y_VFB_2013_2 = df_VFB_2013_2.iloc[0]
Y_VFB_2014_2 = df_VFB_2014_2.iloc[0]
Y_VFB_2015_2 = df_VFB_2015_2.iloc[0]
Y_VFB_2016_2 = df_VFB_2016_2.iloc[0]
Y_VFB_2017_2 = df_VFB_2017_2.iloc[0]
Y_VFB_2018_2 = df_VFB_2018_2.iloc[0]
Y_VFB_2019_2 = df_VFB_2019_2.iloc[0]

Y_VFB_2020_2 = df_VFB_2020_2.iloc[0]
Y_VFB_2021_2 = df_VFB_2021_2.iloc[0]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(20, 10))
plt.plot(months,Y_VFB_2004_2,color="purple",marker="o")
plt.plot(months,Y_VFB_2005_2,color="green",marker="v")
plt.plot(months,Y_VFB_2006_2,color="orange",marker="1")
plt.plot(months,Y_VFB_2007_2,color="red",marker="^")
plt.plot(months,Y_VFB_2008_2,color="blue",marker="2")
plt.plot(months,Y_VFB_2009_2,color="lightblue",marker="3")

plt.plot(months,Y_VFB_2010_2,color="pink",marker="4")
plt.plot(months,Y_VFB_2011_2,color="tomato",marker="+")
plt.plot(months,Y_VFB_2012_2,color="dodgerblue",marker="x")
plt.plot(months,Y_VFB_2013_2,color="lawngreen",marker="|")
plt.plot(months,Y_VFB_2014_2,color="firebrick",marker="8")
plt.plot(months,Y_VFB_2015_2,color="violet",marker="s")
plt.plot(months,Y_VFB_2016_2,color="blueviolet",marker="*")
plt.plot(months,Y_VFB_2017_2,color="navy",marker="h")
plt.plot(months,Y_VFB_2018_2,color="royalblue",marker="D")
plt.plot(months,Y_VFB_2019_2,color="crimson",marker="_")

plt.plot(months,Y_VFB_2020_2,color="aquamarine",marker="o")
plt.plot(months,Y_VFB_2021_2,color="cyan",marker="v")

plt.legend(["2004","2005","2006","2007","2008","2009",
            "2010","2011","2012","2013","2014","2015",
            "2016","2017","2018","2019","2020","2021"])

plt.ylabel('Index of physical volume base 2013=100.')
plt.xlabel('Month')
plt.title("Secondary activities")
plt.grid(True)

plt.show()

# %% [markdown]
# ##### Índice de volumen físico base 2013=100|Actividades secundarias|21---Minería

# %%
Y_VFB_2004_2 = df_VFB_2004_2.iloc[1]
Y_VFB_2005_2 = df_VFB_2005_2.iloc[1]
Y_VFB_2006_2 = df_VFB_2006_2.iloc[1]
Y_VFB_2007_2 = df_VFB_2007_2.iloc[1]
Y_VFB_2008_2 = df_VFB_2008_2.iloc[1]
Y_VFB_2009_2 = df_VFB_2009_2.iloc[1]

Y_VFB_2010_2 = df_VFB_2010_2.iloc[1]
Y_VFB_2011_2 = df_VFB_2011_2.iloc[1]
Y_VFB_2012_2 = df_VFB_2012_2.iloc[1]
Y_VFB_2013_2 = df_VFB_2013_2.iloc[1]
Y_VFB_2014_2 = df_VFB_2014_2.iloc[1]
Y_VFB_2015_2 = df_VFB_2015_2.iloc[1]
Y_VFB_2016_2 = df_VFB_2016_2.iloc[1]
Y_VFB_2017_2 = df_VFB_2017_2.iloc[1]
Y_VFB_2018_2 = df_VFB_2018_2.iloc[1]
Y_VFB_2019_2 = df_VFB_2019_2.iloc[1]

Y_VFB_2020_2 = df_VFB_2020_2.iloc[1]
Y_VFB_2021_2 = df_VFB_2021_2.iloc[1]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(20, 10))
plt.plot(months,Y_VFB_2004_2,color="purple",marker="o")
plt.plot(months,Y_VFB_2005_2,color="green",marker="v")
plt.plot(months,Y_VFB_2006_2,color="orange",marker="1")
plt.plot(months,Y_VFB_2007_2,color="red",marker="^")
plt.plot(months,Y_VFB_2008_2,color="blue",marker="2")
plt.plot(months,Y_VFB_2009_2,color="lightblue",marker="3")

plt.plot(months,Y_VFB_2010_2,color="pink",marker="4")
plt.plot(months,Y_VFB_2011_2,color="tomato",marker="+")
plt.plot(months,Y_VFB_2012_2,color="dodgerblue",marker="x")
plt.plot(months,Y_VFB_2013_2,color="lawngreen",marker="|")
plt.plot(months,Y_VFB_2014_2,color="firebrick",marker="8")
plt.plot(months,Y_VFB_2015_2,color="violet",marker="s")
plt.plot(months,Y_VFB_2016_2,color="blueviolet",marker="*")
plt.plot(months,Y_VFB_2017_2,color="navy",marker="h")
plt.plot(months,Y_VFB_2018_2,color="royalblue",marker="D")
plt.plot(months,Y_VFB_2019_2,color="crimson",marker="_")

plt.plot(months,Y_VFB_2020_2,color="aquamarine",marker="o")
plt.plot(months,Y_VFB_2021_2,color="cyan",marker="v")

plt.legend(["2004","2005","2006","2007","2008","2009",
            "2010","2011","2012","2013","2014","2015",
            "2016","2017","2018","2019","2020","2021"])

plt.ylabel('Index of physical volume base 2013=100.')
plt.xlabel('Month')
plt.title("Secondary activities|21---Mining")
plt.grid(True)

plt.show()

# %% [markdown]
# ##### Índice de volumen físico base 2013=100|Actividades secundarias|22---Generación, transmisión y distribución de energía eléctrica, suministro de agua y de gas por ductos al consumidor final

# %%
Y_VFB_2004_2 = df_VFB_2004_2.iloc[2]
Y_VFB_2005_2 = df_VFB_2005_2.iloc[2]
Y_VFB_2006_2 = df_VFB_2006_2.iloc[2]
Y_VFB_2007_2 = df_VFB_2007_2.iloc[2]
Y_VFB_2008_2 = df_VFB_2008_2.iloc[2]
Y_VFB_2009_2 = df_VFB_2009_2.iloc[2]

Y_VFB_2010_2 = df_VFB_2010_2.iloc[2]
Y_VFB_2011_2 = df_VFB_2011_2.iloc[2]
Y_VFB_2012_2 = df_VFB_2012_2.iloc[2]
Y_VFB_2013_2 = df_VFB_2013_2.iloc[2]
Y_VFB_2014_2 = df_VFB_2014_2.iloc[2]
Y_VFB_2015_2 = df_VFB_2015_2.iloc[2]
Y_VFB_2016_2 = df_VFB_2016_2.iloc[2]
Y_VFB_2017_2 = df_VFB_2017_2.iloc[2]
Y_VFB_2018_2 = df_VFB_2018_2.iloc[2]
Y_VFB_2019_2 = df_VFB_2019_2.iloc[2]

Y_VFB_2020_2 = df_VFB_2020_2.iloc[2]
Y_VFB_2021_2 = df_VFB_2021_2.iloc[2]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(20, 10))
plt.plot(months,Y_VFB_2004_2,color="purple",marker="o")
plt.plot(months,Y_VFB_2005_2,color="green",marker="v")
plt.plot(months,Y_VFB_2006_2,color="orange",marker="1")
plt.plot(months,Y_VFB_2007_2,color="red",marker="^")
plt.plot(months,Y_VFB_2008_2,color="blue",marker="2")
plt.plot(months,Y_VFB_2009_2,color="lightblue",marker="3")

plt.plot(months,Y_VFB_2010_2,color="pink",marker="4")
plt.plot(months,Y_VFB_2011_2,color="tomato",marker="+")
plt.plot(months,Y_VFB_2012_2,color="dodgerblue",marker="x")
plt.plot(months,Y_VFB_2013_2,color="lawngreen",marker="|")
plt.plot(months,Y_VFB_2014_2,color="firebrick",marker="8")
plt.plot(months,Y_VFB_2015_2,color="violet",marker="s")
plt.plot(months,Y_VFB_2016_2,color="blueviolet",marker="*")
plt.plot(months,Y_VFB_2017_2,color="navy",marker="h")
plt.plot(months,Y_VFB_2018_2,color="royalblue",marker="D")
plt.plot(months,Y_VFB_2019_2,color="crimson",marker="_")

plt.plot(months,Y_VFB_2020_2,color="aquamarine",marker="o")
plt.plot(months,Y_VFB_2021_2,color="cyan",marker="v")

plt.legend(["2004","2005","2006","2007","2008","2009",
            "2010","2011","2012","2013","2014","2015",
            "2016","2017","2018","2019","2020","2021"])

plt.ylabel('Index of physical volume base 2013=100.')
plt.xlabel('Month')
plt.title("Secondary activities|22---Generation, transmission and distribution of electrical energy, supply of water and gas through pipelines to the final consumer")
plt.grid(True)

plt.show()

# %% [markdown]
# ##### Índice de volumen físico base 2013=100|Actividades secundarias|23---Construcción

# %%
Y_VFB_2004_2 = df_VFB_2004_2.iloc[3]
Y_VFB_2005_2 = df_VFB_2005_2.iloc[3]
Y_VFB_2006_2 = df_VFB_2006_2.iloc[3]
Y_VFB_2007_2 = df_VFB_2007_2.iloc[3]
Y_VFB_2008_2 = df_VFB_2008_2.iloc[3]
Y_VFB_2009_2 = df_VFB_2009_2.iloc[3]

Y_VFB_2010_2 = df_VFB_2010_2.iloc[3]
Y_VFB_2011_2 = df_VFB_2011_2.iloc[3]
Y_VFB_2012_2 = df_VFB_2012_2.iloc[3]
Y_VFB_2013_2 = df_VFB_2013_2.iloc[3]
Y_VFB_2014_2 = df_VFB_2014_2.iloc[3]
Y_VFB_2015_2 = df_VFB_2015_2.iloc[3]
Y_VFB_2016_2 = df_VFB_2016_2.iloc[3]
Y_VFB_2017_2 = df_VFB_2017_2.iloc[3]
Y_VFB_2018_2 = df_VFB_2018_2.iloc[3]
Y_VFB_2019_2 = df_VFB_2019_2.iloc[3]

Y_VFB_2020_2 = df_VFB_2020_2.iloc[3]
Y_VFB_2021_2 = df_VFB_2021_2.iloc[3]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(20, 10))
plt.plot(months,Y_VFB_2004_2,color="purple",marker="o")
plt.plot(months,Y_VFB_2005_2,color="green",marker="v")
plt.plot(months,Y_VFB_2006_2,color="orange",marker="1")
plt.plot(months,Y_VFB_2007_2,color="red",marker="^")
plt.plot(months,Y_VFB_2008_2,color="blue",marker="2")
plt.plot(months,Y_VFB_2009_2,color="lightblue",marker="3")

plt.plot(months,Y_VFB_2010_2,color="pink",marker="4")
plt.plot(months,Y_VFB_2011_2,color="tomato",marker="+")
plt.plot(months,Y_VFB_2012_2,color="dodgerblue",marker="x")
plt.plot(months,Y_VFB_2013_2,color="lawngreen",marker="|")
plt.plot(months,Y_VFB_2014_2,color="firebrick",marker="8")
plt.plot(months,Y_VFB_2015_2,color="violet",marker="s")
plt.plot(months,Y_VFB_2016_2,color="blueviolet",marker="*")
plt.plot(months,Y_VFB_2017_2,color="navy",marker="h")
plt.plot(months,Y_VFB_2018_2,color="royalblue",marker="D")
plt.plot(months,Y_VFB_2019_2,color="crimson",marker="_")

plt.plot(months,Y_VFB_2020_2,color="aquamarine",marker="o")
plt.plot(months,Y_VFB_2021_2,color="cyan",marker="v")

plt.legend(["2004","2005","2006","2007","2008","2009",
            "2010","2011","2012","2013","2014","2015",
            "2016","2017","2018","2019","2020","2021"])

plt.ylabel('Index of physical volume base 2013=100.')
plt.xlabel('Month')
plt.title("Secondary activities|23---Construction")
plt.grid(True)

plt.show()

# %% [markdown]
# ##### Índice de volumen físico base 2013=100|Actividades secundarias|31-33---Industrias manufactureras

# %%
Y_VFB_2004_2 = df_VFB_2004_2.iloc[4]
Y_VFB_2005_2 = df_VFB_2005_2.iloc[4]
Y_VFB_2006_2 = df_VFB_2006_2.iloc[4]
Y_VFB_2007_2 = df_VFB_2007_2.iloc[4]
Y_VFB_2008_2 = df_VFB_2008_2.iloc[4]
Y_VFB_2009_2 = df_VFB_2009_2.iloc[4]

Y_VFB_2010_2 = df_VFB_2010_2.iloc[4]
Y_VFB_2011_2 = df_VFB_2011_2.iloc[4]
Y_VFB_2012_2 = df_VFB_2012_2.iloc[4]
Y_VFB_2013_2 = df_VFB_2013_2.iloc[4]
Y_VFB_2014_2 = df_VFB_2014_2.iloc[4]
Y_VFB_2015_2 = df_VFB_2015_2.iloc[4]
Y_VFB_2016_2 = df_VFB_2016_2.iloc[4]
Y_VFB_2017_2 = df_VFB_2017_2.iloc[4]
Y_VFB_2018_2 = df_VFB_2018_2.iloc[4]
Y_VFB_2019_2 = df_VFB_2019_2.iloc[4]

Y_VFB_2020_2 = df_VFB_2020_2.iloc[4]
Y_VFB_2021_2 = df_VFB_2021_2.iloc[4]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(20, 10))
plt.plot(months,Y_VFB_2004_2,color="purple",marker="o")
plt.plot(months,Y_VFB_2005_2,color="green",marker="v")
plt.plot(months,Y_VFB_2006_2,color="orange",marker="1")
plt.plot(months,Y_VFB_2007_2,color="red",marker="^")
plt.plot(months,Y_VFB_2008_2,color="blue",marker="2")
plt.plot(months,Y_VFB_2009_2,color="lightblue",marker="3")

plt.plot(months,Y_VFB_2010_2,color="pink",marker="4")
plt.plot(months,Y_VFB_2011_2,color="tomato",marker="+")
plt.plot(months,Y_VFB_2012_2,color="dodgerblue",marker="x")
plt.plot(months,Y_VFB_2013_2,color="lawngreen",marker="|")
plt.plot(months,Y_VFB_2014_2,color="firebrick",marker="8")
plt.plot(months,Y_VFB_2015_2,color="violet",marker="s")
plt.plot(months,Y_VFB_2016_2,color="blueviolet",marker="*")
plt.plot(months,Y_VFB_2017_2,color="navy",marker="h")
plt.plot(months,Y_VFB_2018_2,color="royalblue",marker="D")
plt.plot(months,Y_VFB_2019_2,color="crimson",marker="_")

plt.plot(months,Y_VFB_2020_2,color="aquamarine",marker="o")
plt.plot(months,Y_VFB_2021_2,color="cyan",marker="v")

plt.legend(["2004","2005","2006","2007","2008","2009",
            "2010","2011","2012","2013","2014","2015",
            "2016","2017","2018","2019","2020","2021"])

plt.ylabel('Index of physical volume base 2013=100.')
plt.xlabel('Month')
plt.title("Secondary activities|31-33---Manufacturing industries")
plt.grid(True)

plt.show()

# %% [markdown]
# #### Diferencia entre Años.

# %% [markdown]
# ##### Método 1

# %%
df_VFB_2004 = df_arr_VFB.loc[:,lst_VFB_2004].iloc[:,-1]
df_VFB_2005 = df_arr_VFB.loc[:,lst_VFB_2005].iloc[:,-1]
df_VFB_2006 = df_arr_VFB.loc[:,lst_VFB_2006].iloc[:,-1]
df_VFB_2007 = df_arr_VFB.loc[:,lst_VFB_2007].iloc[:,-1]
df_VFB_2008 = df_arr_VFB.loc[:,lst_VFB_2008].iloc[:,-1]
df_VFB_2009 = df_arr_VFB.loc[:,lst_VFB_2009].iloc[:,-1]

df_VFB_2010 = df_arr_VFB.loc[:,lst_VFB_2010].iloc[:,-1]
df_VFB_2011 = df_arr_VFB.loc[:,lst_VFB_2011].iloc[:,-1]
df_VFB_2012 = df_arr_VFB.loc[:,lst_VFB_2012].iloc[:,-1]
df_VFB_2013 = df_arr_VFB.loc[:,lst_VFB_2013].iloc[:,-1]
df_VFB_2014 = df_arr_VFB.loc[:,lst_VFB_2014].iloc[:,-1]
df_VFB_2015 = df_arr_VFB.loc[:,lst_VFB_2015].iloc[:,-1]
df_VFB_2016 = df_arr_VFB.loc[:,lst_VFB_2016].iloc[:,-1]
df_VFB_2017 = df_arr_VFB.loc[:,lst_VFB_2017].iloc[:,-1]
df_VFB_2018 = df_arr_VFB.loc[:,lst_VFB_2018].iloc[:,-1]
df_VFB_2019 = df_arr_VFB.loc[:,lst_VFB_2019].iloc[:,-1]

df_VFB_2020 = df_arr_VFB.loc[:,lst_VFB_2020].iloc[:,-1]
df_VFB_2021 = df_arr_VFB.loc[:,lst_VFB_2021].iloc[:,-1]

# %%
abs(df_VFB_2013 - df_VFB_2021)
# Out:
# Índice de volumen físico base 2013=100|Actividades secundarias                                                                                                                                  0.935085
# Índice de volumen físico base 2013=100|Actividades secundarias|21---Minería                                                                                                                     7.734892
# Índice de volumen físico base 2013=100|Actividades secundarias|22---Generación, transmisión y distribución de energía eléctrica, suministro de agua y de gas por ductos al consumidor final     9.004371
# Índice de volumen físico base 2013=100|Actividades secundarias|23---Construcción                                                                                                               12.495286
# ...

# %% [markdown]
# ##### Método 2

# %%
df_VFB_2004 = df_arr_VFB.loc[:,lst_VFB_2004].iloc[:,0:-1]
df_VFB_2005 = df_arr_VFB.loc[:,lst_VFB_2005].iloc[:,0:-1]
df_VFB_2006 = df_arr_VFB.loc[:,lst_VFB_2006].iloc[:,0:-1]
df_VFB_2007 = df_arr_VFB.loc[:,lst_VFB_2007].iloc[:,0:-1]
df_VFB_2008 = df_arr_VFB.loc[:,lst_VFB_2008].iloc[:,0:-1]
df_VFB_2009 = df_arr_VFB.loc[:,lst_VFB_2009].iloc[:,0:-1]

df_VFB_2010 = df_arr_VFB.loc[:,lst_VFB_2010].iloc[:,0:-1]
df_VFB_2011 = df_arr_VFB.loc[:,lst_VFB_2011].iloc[:,0:-1]
df_VFB_2012 = df_arr_VFB.loc[:,lst_VFB_2012].iloc[:,0:-1]
df_VFB_2013 = df_arr_VFB.loc[:,lst_VFB_2013].iloc[:,0:-1]
df_VFB_2014 = df_arr_VFB.loc[:,lst_VFB_2014].iloc[:,0:-1]
df_VFB_2015 = df_arr_VFB.loc[:,lst_VFB_2015].iloc[:,0:-1]
df_VFB_2016 = df_arr_VFB.loc[:,lst_VFB_2016].iloc[:,0:-1]
df_VFB_2017 = df_arr_VFB.loc[:,lst_VFB_2017].iloc[:,0:-1]
df_VFB_2018 = df_arr_VFB.loc[:,lst_VFB_2018].iloc[:,0:-1]
df_VFB_2019 = df_arr_VFB.loc[:,lst_VFB_2019].iloc[:,0:-1]

df_VFB_2020 = df_arr_VFB.loc[:,lst_VFB_2020].iloc[:,0:-1]
df_VFB_2021 = df_arr_VFB.loc[:,lst_VFB_2021].iloc[:,0:-1]

# %%
df_VFB_2013 = df_arr_VFB.loc[:,lst_VFB_2013].iloc[:,0:-1]
df_VFB_2013.iloc[0].mean()
# Out:
# 100.00000000000007

# %%
df_VFB_2021 = df_arr_VFB.loc[:,lst_VFB_2021].iloc[:,0:-1]
df_VFB_2021.iloc[0].mean()
# Out:
# 100.93508529696366

# %%
# Calculo de la diferencia entre el 2021 y 2013
for i in range(5):
  print(df_VFB_2013.iloc[i].name)
  print(round(abs(df_VFB_2013.iloc[i].mean() - df_VFB_2021.iloc[i].mean()),6),"\n")
# Out:
# Índice de volumen físico base 2013=100|Actividades secundarias
# 0.935085
#
# Índice de volumen físico base 2013=100|Actividades secundarias|21---Minería
# 7.734892
#
# Índice de volumen físico base 2013=100|Actividades secundarias|22---Generación, transmisión y distribución de energía eléctrica, suministro de agua y de gas por ductos al consumidor final
# 9.004371
#
# Índice de volumen físico base 2013=100|Actividades secundarias|23---Construcción
# 12.495286
#
# Índice de volumen físico base 2013=100|Actividades secundarias|31-33---Industrias manufactureras
# 2.478988

# %%
# Calculo de la diferencia entre el 2021 y 2004
for i in range(5):
  print(df_VFB_2004.iloc[i].name)
  print(round(abs(df_VFB_2004.iloc[i].mean() - df_VFB_2021.iloc[i].mean()),6),"\n")
# Out:
# Índice de volumen físico base 2013=100|Actividades secundarias
# 12.799554
#
# Índice de volumen físico base 2013=100|Actividades secundarias|21---Minería
# 44.117057
#
# Índice de volumen físico base 2013=100|Actividades secundarias|22---Generación, transmisión y distribución de energía eléctrica, suministro de agua y de gas por ductos al consumidor final
# 54.096376
#
# Índice de volumen físico base 2013=100|Actividades secundarias|23---Construcción
# 41.347954
#
# Índice de volumen físico base 2013=100|Actividades secundarias|31-33---Industrias manufactureras
# 2.652801
